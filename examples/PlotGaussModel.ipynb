# %% [markdown]
# Firstly, import the fortran disk model routines and the python likelihood functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from diskmodels import profileell,profilecirc,profileell2d,profilecirc2d
from diskfit import likelihood, utils
from scipy.optimize import minimize

# %% [markdown]
# Load the continuum subtracted spectrum. Establish the redshift and narrow line width in Angstroms.

# %%
fn = '../data/ZTF18aahiqst_subtracted.txt'
wl,flux,fluxerr = utils.readspec(fn)
z = 0.0745
narrowmu = 3.9

# %% [markdown]
# Extract the region of the spectrum containing the double-peaked profile, and store the size of the spectrum in npix

# %%
olambda = 6564.614#6563 # nominal wavelength of the Halpha line (Angstrom)
wavemin = 6300  # minimum wavelength (Angstrom)
wavemax = 6900  # maximum wavelength (Angstrom)
wave = wl/(1+z) # Convert the spectrum to rest frame wavelength
indwave = np.argwhere((wave>wavemin)&(wave<wavemax))[:,0]
wave = np.asarray(wave[indwave],dtype=np.float64)
flux = flux[indwave]
fluxerr = fluxerr[indwave]
npix = wave.shape[0]

# %% [markdown]
# Set all the parameters which will remain fixed to pre-determined values during the fitting

# %%
# No fixed parameters in this example

# %% [markdown]
# Create a dictionary of the fixed parameter names and values

# %%
fixed_labels = []
fixed_values = []
fixed = dict(zip(fixed_labels,fixed_values))

# %% [markdown]
# Set initial guesses for the parameters to be fitted

# %%
broadmu = olambda # Central broad line wavelength in Angstrom
width = 50 # Gaussian width in Angstrom

# %% [markdown]
# Create a dictionary of fitted parameter names and values

# %%
fitted_labels = ['broadmu','width']
initial = [broadmu, width]
fitted = dict(zip(fitted_labels,initial))

# %% [markdown]
# Set wavelengths of narrow emission lines to be included in the fit and create the array of line profiles

# %%
NIIa = 6549.86
Halpha = 6564.614
NIIb = 6585.27
SIIa = 6718.29
SIIb = 6732.68
lines = [Halpha,NIIa,NIIb,SIIa,SIIb]

# %% [markdown]
# Plot initial model against spectrum

# %%
modelguess = likelihood.model_linefit_broad(initial, wave, flux, fluxerr, lines, narrowmu, fixed, fitted)

# %%
plt.figure(figsize=(6,6))
plt.plot(wave,flux,label='data')
plt.plot(wave,modelguess,label='initial guess')
plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Flux')
plt.title('Initial guess')
plt.legend()
plt.show()
plt.clf()

# %% [markdown]
# Establish bounds for fitted parameters. These will be used to make a uniform prior.

# %%
broadmumax = broadmu-20
broadmumin= broadmu+20
widthmin = narrowmu*2
widthmax = 150
diskmins = [broadmumin,widthmin]
diskmax = [broadmumax,widthmax]

# %%
lp = likelihood.logprob_broad(wave, flux, fluxerr, lines, narrowmu, fixed, fitted, diskmins, diskmax)

# %% [markdown]
# Use scipy.optimize.minimize to find a simple solution for the fitted parameters

# %%
nll = lambda *args: -lp(*args)
soln = minimize(nll, initial, method='Nelder-Mead')
modelfit = lp.test(soln.x)
print('Best-fit parameter values', soln.x)
# Out:
# Best-fit parameter values [6566.61500855   72.99004596]

# %%
plt.figure(figsize=(6,6))
plt.plot(wave,flux,label='data')
plt.plot(wave,modelfit,label='fitted model')
plt.xlabel('Wavelength (Angstroms)')
plt.ylabel('Flux')
plt.title('Best fit model')
plt.legend()
plt.show()
plt.clf()

# %% [markdown]
# Now import the emcee module to sample the parameter space, with walkers initialized around the best fit parameters from the previous step. Run the sampler for 1000 iterations and save the progress to file.

# %%
import emcee
pos = soln.x + 1e-2 * soln.x * np.random.randn(20, soln.x.shape[0])
nwalkers, ndim = pos.shape
filename ='broad_emcee.h5'
backend = emcee.backends.HDFBackend(filename)
backend.reset(nwalkers, ndim)
sampler = emcee.EnsembleSampler(
        nwalkers, ndim, lp, args=(), backend=backend
    )
sampler.run_mcmc(pos, 400, progress=True)
# Out:
# 100%|███████████████████████████████████| 400/400 [00:26<00:00, 14.98it/s]
# State([[6566.59304457   72.55356521]
#  [6566.74023681   72.65321968]
#  [6566.49927045   73.00716771]
#  [6567.07605777   73.5679859 ]
#  [6566.94428721   72.8499008 ]
#  [6566.70301549   72.81593775]
#  [6566.36417304   72.96696619]
#  [6566.19707398   73.54020371]
#  [6566.76972425   72.58959609]
#  [6566.53227864   72.84291891]
#  [6566.71607343   72.78071485]
#  [6566.45719924   72.62962106]
#  [6566.6970321    72.59461329]
#  [6566.62426604   72.49523452]
#  [6567.51426144   73.76970756]
#  [6567.07526557   73.43375179]
#  [6566.48273256   73.30566104]
#  [6566.24443453   72.85483271]
#  [6566.80620981   73.22010193]
#  [6566.70048179   73.06156051]], log_prob=[-2887.02230316 -2886.84335095 -2886.07697606 -2887.98640253
#  -2886.8005645  -2886.25743264 -2886.29910927 -2889.24702178
#  -2887.209      -2886.1149179  -2886.36314357 -2886.65324884
#  -2887.00355291 -2887.36788923 -2890.96601458 -2887.44772869
#  -2886.76563046 -2886.62176578 -2886.32722041 -2886.0464549 ], blobs=None, random_state=('MT19937', array([3506503328, 1985305545,  790392990, 2775644187, 2286646709,
#        1654176485,  625832421, 3371448151, 2715963799, 2384731187,
#        1699376416, 3240883077, 2409865417, 1182623656,  929809003,
#         635782716, 2641269984, 2218009915, 2663306706, 3875773182,
#         796327889, 4256218704,  709832978, 1270632671,  550200730,
#        2098025745, 1380827453,  137154666, 2241054182, 3816551076,
#        1692916316,    2907710, 3756894466,  153540051, 1406254501,
#         993685060, 2851428310, 2328312644,  152238917, 1886683252,
#          36737386, 2717890527,  891551210, 2314235284,  591914538,
#        2793791587, 4285023620,  703004270,  174553269,  451972091,
#        1152009550, 1792069381, 1845141882, 2289765049, 4185081543,
#          64770142,  630843650, 3402059149, 2878879234, 3291782237,
#        1062086244, 2218903728,  349938737, 3628576047,  868187170,
#        1550276648,  331482487,  333083200, 1890475280, 3797657831,
#        1346849320, 1837884531, 2365982070, 4226248598, 3712438862,
#         634865771,  464510891, 1347421285,  762735822, 3742034268,
#        2261876459, 1815784579,  251382983,  741598203, 1360355820,
#        1090051550, 3981651896, 4028735741, 2288328224, 4084978667,
#        4288139675,  414512412,  764514661,  657736051, 4284668173,
#        3944779912, 2289460032, 1428508047, 1893620493, 3750323675,
#        3954809217, 3966095896, 3471575898,  250780252, 3483649578,
#        1615788913,  848583136,  661220176,  716602065, 4236969060,
#        3571824033, 2544897232,  621044132, 2238024335, 3881173344,
#        3617062004,  559421155, 1078367930, 1784178911,   20778652,
#        1969391666, 1801751686, 1532517835, 3427172719, 1539121608,
#        1606298959, 2083813045,   56146735,  180174376,  675109908,
#         494625010,  403808103,  453469008,  490411111,  416415561,
#        2619654284, 2188811316, 1839349895, 4115282465, 1208769707,
#        3148874685, 2770595881, 1004939843, 2888110715, 2359782406,
#        1085584249, 2869729630, 2835377312, 1375789802, 1784231138,
#        1534081215, 4123955533, 2108581458, 3398977037, 4064662768,
#        1382765362,  309262755, 1375560409, 1506706060, 4034830221,
#        2852477760,  169693230, 3922011868,   30547564, 1830348920,
#         925616820, 3708920339,  499439901,  803576325,  734158080,
#        4050142572, 4119826217, 2702464755, 3837339333, 1261201254,
#        1560441537, 2453151253, 1231155871, 3005648818,  734335590,
#         791717747, 1663635467, 2952418027, 1411430694, 2680982753,
#        1329007678, 3722137751, 2893196404, 3298463881, 2449136548,
#        2039244379, 2664987707,  459454776, 1436031938, 3079854478,
#        2547280065, 2435473418, 3885355272, 2419389239, 3122443680,
#         758946076,  289986297, 1397113942, 1735757019, 3314676199,
#        3321879056, 1260556153, 1975970333, 3989419998, 3525639691,
#        3914980372, 2493432192, 3838156856, 3924115602,    9366982,
#         171583548, 1879037336, 3679271593, 1444490395, 3636447618,
#        3662238587, 3120477598,  795323143, 3071975416, 2825534855,
#        1695161325, 3707050185, 3223748615, 2386232277, 4082315528,
#        2683726190, 1895523276, 1383802889, 4041106076, 1253423237,
#        2612190627, 1124720854, 1117363190, 1728146775, 2654294802,
#        1756381813,  474796575, 2169593689, 3743749973, 1778509395,
#        2337386163, 2987523070, 1809294765, 1189027786,  629555685,
#        1861005939, 1434795007, 2747146030, 2050549086, 2630924404,
#        1967232102, 1267446558,  792010589, 3960727614, 1283434423,
#         763876238, 4282388952, 4111306209, 2686969482, 1938282350,
#        1350970350, 2627413069, 1727315305,   73868548, 1871060340,
#        1140654796, 3640681289, 2958561806,  126458396,  483841414,
#        3236339664, 3552133170, 2290408614, 2074655849, 2655637595,
#         236797064, 2928142348, 3441241604, 3769543571, 2261725622,
#         488325062,  823029334, 1428594656, 2849658863, 2000918520,
#        1322071913, 3353207706, 4060342301, 1977616350,  398844169,
#        2960804595, 3712927349, 1681343248, 1811599742, 1209840952,
#        1190053292, 3717487206, 1598995123,   15095034, 1199141605,
#        2334777585,  929629328, 1171035023, 4062327726,  136669899,
#        2071353132,  264913434, 2122108785,  194345623, 3867802787,
#        3765770898, 1921094674, 2940679312,  891378241, 1735836955,
#        1463485764, 4078163688, 1824187569, 3499109540, 1512977702,
#        3386128774, 1119264298, 2148102478,  882511168,  156877707,
#        1721592053, 1967970533, 2278851401, 1808455563, 3372165807,
#        1453176485,  205992188, 3355654847, 2026915009, 3519182656,
#        2115254069,  766760757, 2679518286, 1432533506, 1899856608,
#        4280814049, 2943100412,  715543194, 2175104099, 2182134994,
#        3327173915, 3250394314, 1922142639, 2306965330, 2129213232,
#        1463329487, 2221609457, 3294160191, 1201311897, 3326100576,
#         650926710, 3430154150, 4154112360,  549575265,  331392453,
#        2939141291, 1673323717, 3174759948,   97867601, 1930696956,
#        3695720739, 1083853671, 2795283584,  221835689, 2389099676,
#        1496947813,  255198139, 1621699521, 2113031998, 3518776788,
#         738319871,  482747250,  388151300, 1606333616, 3428373169,
#         938635562,   90441557,  126115736, 1885166449, 1549219197,
#        1195014734,  514868192, 1111643691, 4028223663, 3633955083,
#        2983605784,  190229171, 1827377422, 3325710219, 2716817658,
#        2193488495, 3049008432, 1769436861, 1655423749, 2906294249,
#        3846067145, 3853699632,   76193071, 1471796998, 1964507981,
#        4107605065, 2880277610, 2763643337,  530727945, 2724271104,
#        3581809941, 2814032517, 1519441196, 3665902425,  598076223,
#        3120769195,  912719743, 3862384377, 3940343553, 3134535797,
#        1463252955, 2728573002, 3538387624, 1174784562,  322059002,
#        2539516341, 2692383772, 1841131230, 2940371684, 3072852655,
#         298455717, 2333211644, 2120554744, 1136636153, 4170125142,
#         505759482, 1842283454, 2612496923, 2061774194, 3342432815,
#        1292678744, 2488638077, 2730545525, 1520886337, 3115396743,
#        2420709754, 3652925618, 1282952343,  974351486, 3496345111,
#         836496072, 1054641164, 3008501945, 3265989571, 1781152353,
#         141633348, 3276935929, 3993358465,  370782658, 2069167635,
#        2834446215, 3690666483, 2120118119, 2121480520,  665820228,
#        2423262216, 1455134913, 1950299901, 1046129570,  548454205,
#        3479364457,  481326218, 2369883472, 4144103112, 3388678069,
#        2207207368,  811043355,  696602700, 1621840173, 3588647674,
#        1907062205,  112843099, 3707055128,  769028425, 1476029028,
#        2985503581, 3468030746, 2251160863, 1749701965,  633975822,
#        4046226533, 2917188861, 4206419671, 3892282246,  721204918,
#        1003691888,  193083525,  201544211, 3878977349, 3659508305,
#        3031880315, 2955307211, 1195533272,  455823586, 1184166435,
#        1759087289, 2201633711,  283378119, 3236720455,  359944996,
#        3348794830, 1017054967, 2006460627, 3868410634,  693578757,
#        2822607603, 2671347385, 4064723897, 1730598411,  959045631,
#        2204460172, 1362914955, 2464776220, 1845619703,  842479565,
#        4151608221,   59238321, 1467342378, 3433363501, 2204366824,
#          55794736,  432566376, 1890246485, 1617393083,   91528186,
#        3931609979,  664524403, 3303053403,  499390702, 2419476510,
#         139642302,  601670786, 3564626568, 1959305657,  497743118,
#        1950751677, 4073737600, 2754576437, 1021521245, 3895834084,
#          14760215, 2468355741, 2896952232, 2154132961, 3420138716,
#        3728872156, 2542998417,  769334534, 2945194045, 3761553570,
#        2778624444, 3676481658, 1655965043,  652418728, 4097178467,
#         514534856, 1487827928, 2276584218, 3698432948, 3331347645,
#        3050837500, 4252907879, 1500339399, 3931931869, 3275488294,
#         465619311, 2460450281, 2474695689, 3274508006, 2096685550,
#        4057096601, 4155756876, 3128015324, 1067234645, 2569826011,
#        2358225457, 1455380903,  190727348,  387443762,  814042460,
#         654563599, 2416656125, 1846720715, 1732092903, 3652082520,
#        2530750047, 2856608737, 1603298407,  790560712,   91011018,
#          20899523,  470869379,  477471449, 3013148855, 3785050477,
#        1657218009, 2880004528, 3665222691,   62868714,  889682028,
#         662121331, 2232716266, 1643239398, 3941980735, 2960882781,
#        2041633957,  536361704, 4243871893,  601282019], dtype=uint32), 93, 0, 0.0))

# %% [markdown]
# Print the parameters and uncertainties found by the sampler

# %%
from IPython.display import display, Math
flat_samples = sampler.get_chain(discard=200, flat=True)
for i,l in enumerate(fitted_labels):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], fitted_labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{broadmu} = 6566.630_{-0.311}^{0.311}$
# $\displaystyle \mathrm{width} = 73.047_{-0.376}^{0.333}$

# %% [markdown]
# Make a corner plot of the parameter samples

# %%
import corner
fig = corner.corner(
            flat_samples, labels=fitted_labels)
plt.show()

# %% [markdown]
# Plot the sampler chains

# %%
plt.figure(figsize=(6,6))
fig, axes = plt.subplots(soln.x.shape[0], figsize=(10,3*soln.x.shape[0]), sharex=True)
samples = sampler.get_chain()
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(fitted_labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
    axes[-1].set_xlabel("step number");
plt.show()
plt.clf()

# %% [markdown]
# Plot the range of good fits found by the sampler

# %%
from ultranest.plot import PredictionBand
band = PredictionBand(wave)
inds = np.random.randint(len(flat_samples), size=10)
for ind in inds:
    sample = flat_samples[ind]
    modelfit = lp.test(sample)
    band.add(modelfit)
    plt.plot(wave,modelfit,alpha=0.1)

band.line(color='k',label='model')
# add 1 sigma quantile
band.shade(color='k', alpha=0.5)
# add wider quantile (0.01 .. 0.99)
band.shade(q=0.49, color='gray', alpha=0.2);

plt.plot(wave,flux,label='data')
plt.title('Best fit model found by the emcee sampler')
plt.legend(fontsize=14)
plt.xlabel("x")
plt.ylabel("y");
plt.show()
plt.clf()
